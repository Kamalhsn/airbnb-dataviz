# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Objective

# %% [markdown]
# ## Datasets Overview
# - Berlin
# - Bangkok

# %% [markdown]
# ## Schema Inspection

# %% [markdown]
# ## Missing Values Overview

# %% [markdown]
# ## Initial Observations
