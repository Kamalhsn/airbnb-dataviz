# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamalhsn/airbnb-dataviz/blob/main/notebooks/01_data_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Objective

# %% [markdown]
# ## Datasets Overview
# - Berlin
# - Bangkok

# %%
# !git clone https://github.com/Kamalhsn/airbnb-dataviz.git
# Out:
# Cloning into 'airbnb-dataviz'...
# remote: Enumerating objects: 977, done.
# remote: Counting objects: 100% (977/977), done.
# remote: Compressing objects: 100% (947/947), done.
# remote: Total 977 (delta 27), reused 973 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (977/977), 10.94 MiB | 11.49 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# !ls airbnb-dataviz
# Out:
# data  notebooks  README.md  requirements.txt

# %%
import pandas as pd

# Berlin
berlin_listings = pd.read_csv("airbnb-dataviz/data/berlin/listings.csv")
berlin_reviews = pd.read_csv("airbnb-dataviz/data/berlin/reviews.csv")
berlin_neighbourhoods = pd.read_csv("airbnb-dataviz/data/berlin/neighbourhoods.csv")

# Bangkok
bangkok_listings = pd.read_csv("airbnb-dataviz/data/bangkok/listings.csv")
bangkok_reviews = pd.read_csv("airbnb-dataviz/data/bangkok/reviews.csv")
bangkok_neighbourhoods = pd.read_csv("airbnb-dataviz/data/bangkok/neighbourhoods.csv")

# %% [markdown]
# ## Schema Inspection

# %% [markdown]
# ## Missing Values Overview

# %% [markdown]
# ## Initial Observations
